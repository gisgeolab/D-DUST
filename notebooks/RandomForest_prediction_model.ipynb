# %% [markdown]
# # Model prediction with Random Forest Regressor

# %% [markdown]
# ### Import libraries

# %%
import warnings
import numpy as np
from numpy.random import seed
from sklearn.ensemble import RandomForestRegressor
seed(1)
from fs import methods as m
import geopandas as gpd
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
warnings.filterwarnings("ignore")
params = ['0_1_mountains', '0_1_nomountains', '0_01_mountains', '0_01_nomountains']

# %% [markdown]
# ### Configuration
# It possible to set these parameter before running the model:
#
# - **NUMBER_OF_COVARIATES**: It's number of the n features with the highest Borda Count score take as input for the model;
# - **TARGET**: It represents the target variable to be predicted by the model;

# %%
#Number of variables used for training 
NUMBER_OF_COVARIATES = 20
#Configurations of the model
params = ['0_1_mountains', '0_1_nomountains', '0_01_mountains', '0_01_nomountains']
#Period
geopackages = ['0324_0331_2021','0418_0425_2021', '0717_0724_2021','0903_0910_2021','1007_1014_2021']
#target variable choosen
TARGET = 'pm25_st'


### Data Import

# %% [markdown]
# ### Results
# Final results are finally stored in a Dataframe in which columns are referred to the errors and accuracy reached by model if it's validated by:
# - values interpolated from ARPA sensors (which are used also by the training);
# - values of CAMS model;

# %%
#With these nested loops a training for each period and configuratio is performed
for par in params:
    #results are stored in a df
    results = pd.DataFrame(columns=['MAE_sensor', 'MSE_sensor', 'R2_sensor', 'MAE_cams', 'MSE_cams', 'R2_cams'])
    for index, grid in enumerate(geopackages):
        
        #Declaration of RF regressor initialized for each period
        regressor = RandomForestRegressor(n_estimators=300)
        #Data acquisition
        if(par[0:3] == '0_1'):
            data = gpd.read_file('assets/grids_0_1/grid_0_1_'+ grid+'.gpkg')
            data = m.process_data(data, 10, TARGET)
        else:
            data = gpd.read_file('assets/grids_0_01/grid_0_01_'+ grid+'.gpkg')
            data = m.process_data(data, 30, TARGET)

        if(par[-11:]=='nomountains'):
            data = data[data['clim_zone'] > 3]
        data.pop('clim_zone')
        data = data[~data[TARGET].isnull()]
        data = data.dropna(axis=1).dropna(axis=0)
        labels = pd.read_csv('assets/fs_results/'+TARGET + par + '_features_model.csv')['Features'].tolist()

        #Store dataset in x and y variables
        X = pd.DataFrame(data=data, columns=labels ).dropna(axis = 1)
        cams_model = X['pm25_cams'].to_numpy()
        X.pop('pm25_cams')

        X = X.iloc[:, :NUMBER_OF_COVARIATES].to_numpy()
        Y = pd.DataFrame(data=data, columns=[TARGET] )

        Y = Y.values.ravel()


        y1 = np.array(Y)
        mae_list1 = []
        mse_list1 = []
        r2_list1 = []
        mae_list2 = []
        mse_list2 = []
        r2_list2 = []
        print('---------'+ grid +'---------')
        
        #K-Fold is applied
        skf = KFold(n_splits=5, shuffle = True)
        i = 1
        for train_index, test_index in skf.split(X):
            print("Iteration n°:  ", i)
            i = i + 1

            X_train = X[train_index]
            X_test = X[test_index]
            y_train, y_test = y1[train_index], y1[test_index]
            cams_model_validation = cams_model[test_index]
            sc = StandardScaler()
            X_train = sc.fit_transform(X_train)
            X_test = sc.transform(X_test)
            
            #training 
            regressor.fit(X_train, y_train)
            
            #validation with testset
            y_pred = regressor.predict(X_test)
            
            #result are stored
            mae = mean_absolute_error(y_test, y_pred)
            mse = mean_squared_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)
            mae_list1.append(mae)
            mse_list1.append(mse)
            r2_list1.append(r2)
                   
            #validation with CAMS model values
            mae = mean_absolute_error(y_test, cams_model_validation)
            mse = mean_squared_error(y_test, cams_model_validation)
            r2 = r2_score(y_test, cams_model_validation)
            
            #result are stored
            mae_list2.append(mae)
            mse_list2.append(mse)
            r2_list2.append(r2)
       
        #At the end of the K-Fold results obtained are averaged
        avg_mae1 = np.mean(mae_list1)
        avg_mse1 = np.mean(mse_list1)
        avg_r21 = np.mean(r2_list1)
        
        avg_mae2 = np.mean(mae_list2)
        avg_mse2 = np.mean(mse_list2)
        avg_r22 = np.mean(r2_list2)



        print('---------VALIDATION (ARPA)  ---------')
        print('Mean Absolute Error: ',avg_mae1)
        print('Mean Squared Error: ',avg_mse1)
        print('R2 score: ',avg_r21)
        print('---------VALIDATION (CAMS) ---------')
        print('Mean Absolute Error: ',avg_mae2)
        print('Mean Squared Error: ',avg_mse2)
        print('R2 score: ',avg_r22)


        mae_list1 = []
        mse_list1 = []
        r2_list1 = []
        mae_list2 = []
        mse_list2 = []
        r2_list2 = []


        results.loc[index]= [round(avg_mae1,3), round(avg_mse1, 3), round(avg_r21, 3), round(avg_mae2,3), round(avg_mse2, 3), round(avg_r22, 3)]
        results.rename(index={index: grid}, inplace=True)

    #results are exported
    new = results.T
    new.to_excel('assets/test/RF'+TARGET+par+'.xlsx')
    new.to_csv('assets/test/RF'+TARGET+par+'.csv')
# Out:
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.1881633199015988
# Mean Squared Error:  3.0575565104704747
# R2 score:  0.8896079987308804
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  7.800208709370421
# Mean Squared Error:  86.2788155812207
# R2 score:  -2.146964304028448
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.951431670098884
# Mean Squared Error:  1.5015737925854378
# R2 score:  0.7821504282570682
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  6.556384805964745
# Mean Squared Error:  57.59264305401499
# R2 score:  -7.491962328401664
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.5903580691139991
# Mean Squared Error:  0.6255962020949637
# R2 score:  0.6866398138509316
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  2.110376496002494
# Mean Squared Error:  7.54808436807555
# R2 score:  -2.8464707604569943
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.915766863766828
# Mean Squared Error:  1.624856790835549
# R2 score:  0.8488287627150364
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.0601405117250073
# Mean Squared Error:  13.265785748509682
# R2 score:  -0.2579622315327333
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.7553954090241184
# Mean Squared Error:  1.1135726175228604
# R2 score:  0.8496300949008386
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.4781515714542834
# Mean Squared Error:  16.590625742858485
# R2 score:  -1.095589544339686
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.3467494428182925
# Mean Squared Error:  3.233472438558622
# R2 score:  0.8891295359301165
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.229784232784203
# Mean Squared Error:  95.10911686452893
# R2 score:  -2.3123381817984887
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.1326214631657616
# Mean Squared Error:  2.1341862554522697
# R2 score:  0.7366566614316141
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  7.914193535239164
# Mean Squared Error:  76.44143791062837
# R2 score:  -8.545986422332911
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.6084445715963913
# Mean Squared Error:  0.7106185767935455
# R2 score:  0.7082877454022836
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  1.3857079041923128
# Mean Squared Error:  2.8672130544610215
# R2 score:  -0.18452277286052923
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.9086875215564753
# Mean Squared Error:  1.5332978427029698
# R2 score:  0.8548950965225682
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.5812168382487948
# Mean Squared Error:  16.922894401788774
# R2 score:  -0.6323868003614932
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.830738669528883
# Mean Squared Error:  1.2612434712794076
# R2 score:  0.7835744315399271
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.743585073960375
# Mean Squared Error:  18.964449222767445
# R2 score:  -2.372556138365864
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.31418634229643694
# Mean Squared Error:  0.43437122918765747
# R2 score:  0.9883589540890416
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.965736223143566
# Mean Squared Error:  106.41439460854649
# R2 score:  -1.8205616079014812
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.22229617727840636
# Mean Squared Error:  0.1546183867378788
# R2 score:  0.9828707108660776
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  7.566420574175977
# Mean Squared Error:  71.81815826774566
# R2 score:  -7.099099596831297
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.1589069620929267
# Mean Squared Error:  0.0785721752901432
# R2 score:  0.9782647320138385
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  1.9359265717580558
# Mean Squared Error:  6.2132563391555475
# R2 score:  -0.7268215691518057
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.21721149563660433
# Mean Squared Error:  0.1497769829768179
# R2 score:  0.989441902580005
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.574125254150134
# Mean Squared Error:  16.8100531166184
# R2 score:  -0.18045047917161888
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.14451942352845532
# Mean Squared Error:  0.06354200153637439
# R2 score:  0.9922798155170227
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.973749129852332
# Mean Squared Error:  20.988374420360778
# R2 score:  -1.5784142222373103
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.37054092683262085
# Mean Squared Error:  0.4752215128235834
# R2 score:  0.9886045694571906
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  9.152701974298628
# Mean Squared Error:  111.72137308574008
# R2 score:  -1.681665587177968
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.2413141833411713
# Mean Squared Error:  0.18330073705389174
# R2 score:  0.9829346606843087
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.580262149940031
# Mean Squared Error:  86.52984964524401
# R2 score:  -7.131320319841275
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.19325429698168542
# Mean Squared Error:  0.12650685194265918
# R2 score:  0.9665843477367698
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  1.617392112899386
# Mean Squared Error:  3.766114669611228
# R2 score:  0.0039251457008023126
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.24290863025631887
# Mean Squared Error:  0.286429907596053
# R2 score:  0.9831410829134788
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.82950278342284
# Mean Squared Error:  19.28390301631223
# R2 score:  -0.18739366497364354
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.1768839951240077
# Mean Squared Error:  0.10650878674512225
# R2 score:  0.9828520696498548
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  4.192464858402383
# Mean Squared Error:  22.6755238740043
# R2 score:  -2.6744930227269506
