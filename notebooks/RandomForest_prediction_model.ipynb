# %% [markdown]
# # Model prediction with Random Forest Regressor

# %% [markdown]
# ### Import libraries

# %%
import math
import random
import warnings
import numpy as np
from numpy.random import seed
from sklearn.ensemble import RandomForestRegressor
seed(1)
from fs import methods as m
import geopandas as gpd
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
warnings.filterwarnings("ignore")
params = ['0_1_mountains', '0_1_nomountains', '0_01_mountains', '0_01_nomountains']

# %% [markdown]
# ### Configuration
# It possible to set these parameter before running the model:
#
# - **NUMBER_OF_COVARIATES**: It's number of the n features with the highest Borda Count score take as input for the model;
# - **TARGET**: It represents the target variable to be predicted by the model;

# %%
#Number of variables used for training 
NUMBER_OF_COVARIATES = 20
#Configurations of the model
params = ['0_1_mountains', '0_1_nomountains', '0_01_mountains', '0_01_nomountains']
#Period
geopackages = ['0324_0331_2021','0418_0425_2021', '0717_0724_2021','0903_0910_2021','1007_1014_2021']
#target variable choosen
TARGET = 'nh3_st'


### Data Import

# %% [markdown]
# ### Results
# Final results are finally stored in a Dataframe in which columns are referred to the errors and accuracy reached by model if it's validated by:
# - values interpolated from ARPA sensors (which are used also by the training);
# - values of CAMS model;

# %%
#With these nested loops a training for each period and configuratio is performed
for par in params:
    print('\n\n\n\n\n\n\n\n\n')
    print(par)
    #results are stored in a df
    results = pd.DataFrame(columns=['MAE_sensor', 'RMSE_sensor','MSE_sensor', 'R2_sensor', 'MAE_cams', 'RMSE_cams', 'MSE_cams', 'R2_cams'])
    for index, grid in enumerate(geopackages):
        
        #Declaration of RF regressor initialized for each period
        regressor = RandomForestRegressor(n_estimators=300)
        #Data acquisition
        if(par[0:3] == '0_1'):
            data = gpd.read_file('assets/grids_0_1/grid_0_1_'+ grid+'.gpkg')
            data = m.process_data(data, 10, TARGET)
        else:
            data = gpd.read_file('assets/grids_0_01/grid_0_01_'+ grid+'.gpkg')
            data = m.process_data(data, 30, TARGET)

        if(par[-11:]=='nomountains'):
            data = data[data['clim_zone'] > 3]
        data.pop('clim_zone')
        data = data[~data[TARGET].isnull()]
        data = data.dropna(axis=1).dropna(axis=0)
        labels = pd.read_csv('assets/fs_results/'+TARGET + par + '_features_model.csv')['Features'].tolist()
        #Store dataset in x and y variables
        X = pd.DataFrame(data=data, columns=labels ).dropna(axis = 1)
        cams_model = X['pm25_cams'].to_numpy()
        X.pop('pm25_cams')
        
        #using this line of code the modelling will be performed without FS, with labels chosen randomly. (remember to 'comment' the next line of code for doing this)
        #X = X.sample(n=NUMBER_OF_COVARIATES,axis='columns')
        X = X.iloc[:, :NUMBER_OF_COVARIATES]
        X = X.to_numpy()

        Y = pd.DataFrame(data=data, columns=[TARGET] )

        Y = Y.values.ravel()


        y1 = np.array(Y)
        mae_list1 = []
        mse_list1 = []
        rmse_list1 = []
        r2_list1 = []
        mae_list2 = []
        mse_list2 = []
        rmse_list2 = []
        r2_list2 = []
        print('---------'+ grid +'---------')
        
        #K-Fold is applied
        skf = KFold(n_splits=5, shuffle = True)
        i = 1
        for train_index, test_index in skf.split(X):
            print("Iteration n°:  ", i)
            i = i + 1

            X_train = X[train_index]
            X_test = X[test_index]
            y_train, y_test = y1[train_index], y1[test_index]
            cams_model_validation = cams_model[test_index]
            sc = StandardScaler()
            X_train = sc.fit_transform(X_train)
            X_test = sc.transform(X_test)
            
            #training 
            regressor.fit(X_train, y_train)
            
            #validation with testset
            y_pred = regressor.predict(X_test)
            
            #result are stored
            mae = mean_absolute_error(y_test, y_pred)
            mse = mean_squared_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)
            mae_list1.append(mae)
            mse_list1.append(mse)
            rmse_list1.append(math.sqrt(mse))
            r2_list1.append(r2)
                   
            #validation with CAMS model values
            mae = mean_absolute_error(y_test, cams_model_validation)
            mse = mean_squared_error(y_test, cams_model_validation)
            r2 = r2_score(y_test, cams_model_validation)
            
            #result are stored
            mae_list2.append(mae)
            mse_list2.append(mse)
            rmse_list2.append(math.sqrt(mse))
            r2_list2.append(r2)
       
        #At the end of the K-Fold results obtained are averaged
        avg_mae1 = np.mean(mae_list1)
        avg_mse1 = np.mean(mse_list1)
        avg_rmse1 = np.mean(rmse_list1)
        avg_r21 = np.mean(r2_list1)
        
        avg_mae2 = np.mean(mae_list2)
        avg_mse2 = np.mean(mse_list2)
        avg_rmse2 = np.mean(rmse_list2)
        avg_r22 = np.mean(r2_list2)



        print('---------VALIDATION (ARPA)  ---------')
        print('Mean Absolute Error: ',avg_mae1)
        print('Root Mean Squared Error: ',avg_rmse1)
        print('Mean Squared Error: ',avg_mse1)
        print('R2 score: ',avg_r21)
        print('---------VALIDATION (CAMS) ---------')
        print('Mean Absolute Error: ',avg_mae2)
        print('Root Mean Squared Error: ',avg_rmse2)
        print('Mean Squared Error: ',avg_mse2)
        print('R2 score: ',avg_r22)


        mae_list1 = []
        mse_list1 = []
        rmse_list1 = []
        r2_list1 = []
        mae_list2 = []
        mse_list2 = []
        rmse_list2 = []
        r2_list2 = []


        results.loc[index]= [round(avg_mae1,3), round(avg_rmse1, 3), round(avg_mse1, 3), round(avg_r21, 3), round(avg_mae2,3), round(avg_rmse2, 3), round(avg_mse2, 3), round(avg_r22, 3)]
        results.rename(index={index: grid}, inplace=True)

    #results are exported
    new = results.T
    new.to_excel('assets/test/RF'+TARGET+par+'.xlsx')
    new.to_csv('assets/test/RF'+TARGET+par+'.csv')
# Out:
# 0_1_mountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.2385801226614221
# Root Mean Squared Error:  1.7683230300420554
# Mean Squared Error:  3.214620378327326
# R2 score:  0.882832702933006
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  7.800208709370421
# Root Mean Squared Error:  9.26240487943476
# Mean Squared Error:  86.2788155812207
# R2 score:  -2.146964304028448
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.8995053945760239
# Root Mean Squared Error:  1.1327037213627664
# Mean Squared Error:  1.2948024880920685
# R2 score:  0.8118967314638438
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  6.556384805964745
# Root Mean Squared Error:  7.570609745846089
# Mean Squared Error:  57.59264305401499
# R2 score:  -7.491962328401664
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.5656163003744021
# Root Mean Squared Error:  0.7448161081537189
# Mean Squared Error:  0.5709572652833035
# R2 score:  0.7219736200261823
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  2.110376496002494
# Root Mean Squared Error:  2.7448270175843144
# Mean Squared Error:  7.54808436807555
# R2 score:  -2.8464707604569943
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.9867455279160502
# Root Mean Squared Error:  1.3303395521583077
# Mean Squared Error:  1.8016756244151282
# R2 score:  0.8335643583447331
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.0601405117250073
# Root Mean Squared Error:  3.622884851662577
# Mean Squared Error:  13.265785748509682
# R2 score:  -0.2579622315327333
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.7506987977100519
# Root Mean Squared Error:  1.013019436783606
# Mean Squared Error:  1.0668870514802555
# R2 score:  0.8576515110468217
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.4781515714542834
# Root Mean Squared Error:  4.059497751208823
# Mean Squared Error:  16.590625742858485
# R2 score:  -1.095589544339686
#
#
#
#
#
#
#
#
#
#
# 0_1_nomountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.4478590539503782
# Root Mean Squared Error:  1.9404106542457655
# Mean Squared Error:  3.7720548094391466
# R2 score:  0.8717961815956483
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.229784232784203
# Root Mean Squared Error:  9.662925541546777
# Mean Squared Error:  95.10911686452893
# R2 score:  -2.3123381817984887
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.093322830440838
# Root Mean Squared Error:  1.3621942682137753
# Mean Squared Error:  1.8742795231733056
# R2 score:  0.7662349234968933
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  7.914193535239164
# Root Mean Squared Error:  8.714467593344796
# Mean Squared Error:  76.44143791062837
# R2 score:  -8.545986422332911
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.6462044824693469
# Root Mean Squared Error:  0.8682670932977331
# Mean Squared Error:  0.7755143228729866
# R2 score:  0.6827875085497043
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  1.3857079041923128
# Root Mean Squared Error:  1.6718803364697117
# Mean Squared Error:  2.8672130544610215
# R2 score:  -0.18452277286052923
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.8978111167598822
# Root Mean Squared Error:  1.1648026054194847
# Mean Squared Error:  1.3761336840514005
# R2 score:  0.8697920088146631
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.5812168382487948
# Root Mean Squared Error:  4.105317391551236
# Mean Squared Error:  16.922894401788774
# R2 score:  -0.6323868003614932
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.8414511857734924
# Root Mean Squared Error:  1.0804388376908514
# Mean Squared Error:  1.1966040451862654
# R2 score:  0.7926491336085405
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.743585073960375
# Root Mean Squared Error:  4.336270709707383
# Mean Squared Error:  18.964449222767445
# R2 score:  -2.372556138365864
#
#
#
#
#
#
#
#
#
#
# 0_01_mountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.2512346508930299
# Root Mean Squared Error:  0.5030439644240047
# Mean Squared Error:  0.28297230606666374
# R2 score:  0.9923921671400604
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.965736223143566
# Root Mean Squared Error:  10.309557253648219
# Mean Squared Error:  106.41439460854649
# R2 score:  -1.8205616079014812
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.18592108249324174
# Root Mean Squared Error:  0.36086346541802083
# Mean Squared Error:  0.1380272593778616
# R2 score:  0.9846815710230341
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  7.566420574175977
# Root Mean Squared Error:  8.471871846631176
# Mean Squared Error:  71.81815826774566
# R2 score:  -7.099099596831297
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.1469561188515577
# Root Mean Squared Error:  0.2547306014392058
# Mean Squared Error:  0.06614220418471786
# R2 score:  0.9813758980487355
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  1.9359265717580558
# Root Mean Squared Error:  2.4873327724780707
# Mean Squared Error:  6.2132563391555475
# R2 score:  -0.7268215691518057
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.17207130868857126
# Root Mean Squared Error:  0.2849480275647768
# Mean Squared Error:  0.08369585859546491
# R2 score:  0.9942554247886048
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.574125254150134
# Root Mean Squared Error:  4.098752860513672
# Mean Squared Error:  16.8100531166184
# R2 score:  -0.18045047917161888
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.13169614285484196
# Root Mean Squared Error:  0.24008426724110882
# Mean Squared Error:  0.05921259995189872
# R2 score:  0.9928310367213667
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.973749129852332
# Root Mean Squared Error:  4.579550091986564
# Mean Squared Error:  20.988374420360778
# R2 score:  -1.5784142222373103
#
#
#
#
#
#
#
#
#
#
# 0_01_nomountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.34657208843490733
# Root Mean Squared Error:  0.6241127194790393
# Mean Squared Error:  0.410858053015058
# R2 score:  0.9900075595472284
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  9.152701974298628
# Root Mean Squared Error:  10.564352899382273
# Mean Squared Error:  111.72137308574008
# R2 score:  -1.681665587177968
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.23386498459768226
# Root Mean Squared Error:  0.39156639293476597
# Mean Squared Error:  0.15821745176009275
# R2 score:  0.9853444461009324
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.580262149940031
# Root Mean Squared Error:  9.294347166326641
# Mean Squared Error:  86.52984964524401
# R2 score:  -7.131320319841275
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.15645644845512474
# Root Mean Squared Error:  0.2607069740081684
# Mean Squared Error:  0.06861133227672443
# R2 score:  0.9818585228589383
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  1.617392112899386
# Root Mean Squared Error:  1.9400877612536742
# Mean Squared Error:  3.766114669611228
# R2 score:  0.0039251457008023126
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.199076713773807
# Root Mean Squared Error:  0.3266661292384673
# Mean Squared Error:  0.11338860988385321
# R2 score:  0.9931924718914911
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  3.82950278342284
# Root Mean Squared Error:  4.382137899259495
# Mean Squared Error:  19.28390301631223
# R2 score:  -0.18739366497364354
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.14633056459631927
# Root Mean Squared Error:  0.23177900082402347
# Mean Squared Error:  0.054030891964382766
# R2 score:  0.9912572756573967
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  4.192464858402383
# Root Mean Squared Error:  4.759501492810988
# Mean Squared Error:  22.6755238740043
# R2 score:  -2.6744930227269506
