# %% [markdown]
# # Model prediction with Random Forest Regressor

# %% [markdown]
# ### Import libraries

# %%
import math
import random
import warnings
import numpy as np
from numpy.random import seed
from sklearn.ensemble import RandomForestRegressor
seed(1)
from fs import methods as m
import geopandas as gpd
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
warnings.filterwarnings("ignore")
params = ['0_1_mountains', '0_1_nomountains', '0_01_mountains', '0_01_nomountains']

# %% [markdown]
# ### Configuration
# It possible to set these parameter before running the model:
#
# - **NUMBER_OF_COVARIATES**: It's number of the n features with the highest Borda Count score take as input for the model;
# - **TARGET**: It represents the target variable to be predicted by the model;

# %%
#Number of variables used for training 
NUMBER_OF_COVARIATES = 20
#Configurations of the model
params = ['0_1_mountains', '0_1_nomountains', '0_01_mountains', '0_01_nomountains']
#Period
geopackages = ['0324_0331_2021','0418_0425_2021', '0717_0724_2021','0903_0910_2021','1007_1014_2021']
#target variable choosen
TARGET = 'nh3_st'


### Data Import

# %% [markdown]
# ### Results
# Final results are finally stored in a Dataframe in which columns are referred to the errors and accuracy reached by model if it's validated by:
# - values interpolated from ARPA sensors (which are used also by the training);
# - values of CAMS model;

# %%
#With these nested loops a training for each period and configuratio is performed
for par in params:
    print('\n\n\n\n\n\n\n\n\n')
    print(par)
    #results are stored in a df
    results = pd.DataFrame(columns=['MAE_sensor', 'RMSE_sensor','MSE_sensor', 'R2_sensor', 'MAE_cams', 'RMSE_cams', 'MSE_cams', 'R2_cams'])
    for index, grid in enumerate(geopackages):
        
        #Declaration of RF regressor initialized for each period
        regressor = RandomForestRegressor(n_estimators=300)
        #Data acquisition
        if(par[0:3] == '0_1'):
            data = gpd.read_file('assets/grids_0_1/grid_0_1_'+ grid+'.gpkg')
            data = m.process_data(data, 10, TARGET)
        else:
            data = gpd.read_file('assets/grids_0_01/grid_0_01_'+ grid+'.gpkg')
            data = m.process_data(data, 30, TARGET)

        if(par[-11:]=='nomountains'):
            data = data[data['clim_zone'] > 3]
        data.pop('clim_zone')
        data = data[~data[TARGET].isnull()]
        data = data.dropna(axis=1).dropna(axis=0)
        labels = pd.read_csv('assets/fs_results/'+TARGET + par + '_features_model.csv')['Features'].tolist()
        #Store dataset in x and y variables
        X = pd.DataFrame(data=data, columns=labels ).dropna(axis = 1)
        cams_model = X['pm25_cams'].to_numpy()
        X.pop('pm25_cams')
        
        #using this line of code the modelling will be performed without FS, with labels chosen randomly. (remember to 'comment' the next line of code for doing this)
        #X = X.sample(n=NUMBER_OF_COVARIATES,axis='columns')
        X = X.iloc[:, :NUMBER_OF_COVARIATES].to_numpy()
        X = X.to_numpy()

        Y = pd.DataFrame(data=data, columns=[TARGET] )

        Y = Y.values.ravel()


        y1 = np.array(Y)
        mae_list1 = []
        mse_list1 = []
        rmse_list1 = []
        r2_list1 = []
        mae_list2 = []
        mse_list2 = []
        rmse_list2 = []
        r2_list2 = []
        print('---------'+ grid +'---------')
        
        #K-Fold is applied
        skf = KFold(n_splits=5, shuffle = True)
        i = 1
        for train_index, test_index in skf.split(X):
            print("Iteration n°:  ", i)
            i = i + 1

            X_train = X[train_index]
            X_test = X[test_index]
            y_train, y_test = y1[train_index], y1[test_index]
            cams_model_validation = cams_model[test_index]
            sc = StandardScaler()
            X_train = sc.fit_transform(X_train)
            X_test = sc.transform(X_test)
            
            #training 
            regressor.fit(X_train, y_train)
            
            #validation with testset
            y_pred = regressor.predict(X_test)
            
            #result are stored
            mae = mean_absolute_error(y_test, y_pred)
            mse = mean_squared_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)
            mae_list1.append(mae)
            mse_list1.append(mse)
            rmse_list1.append(math.sqrt(mse))
            r2_list1.append(r2)
                   
            #validation with CAMS model values
            mae = mean_absolute_error(y_test, cams_model_validation)
            mse = mean_squared_error(y_test, cams_model_validation)
            r2 = r2_score(y_test, cams_model_validation)
            
            #result are stored
            mae_list2.append(mae)
            mse_list2.append(mse)
            rmse_list2.append(math.sqrt(mse))
            r2_list2.append(r2)
       
        #At the end of the K-Fold results obtained are averaged
        avg_mae1 = np.mean(mae_list1)
        avg_mse1 = np.mean(mse_list1)
        avg_rmse1 = np.mean(rmse_list1)
        avg_r21 = np.mean(r2_list1)
        
        avg_mae2 = np.mean(mae_list2)
        avg_mse2 = np.mean(mse_list2)
        avg_rmse2 = np.mean(rmse_list2)
        avg_r22 = np.mean(r2_list2)



        print('---------VALIDATION (ARPA)  ---------')
        print('Mean Absolute Error: ',avg_mae1)
        print('Root Mean Squared Error: ',avg_rmse1)
        print('Mean Squared Error: ',avg_mse1)
        print('R2 score: ',avg_r21)
        print('---------VALIDATION (CAMS) ---------')
        print('Mean Absolute Error: ',avg_mae2)
        print('Root Mean Squared Error: ',avg_rmse2)
        print('Mean Squared Error: ',avg_mse2)
        print('R2 score: ',avg_r22)


        mae_list1 = []
        mse_list1 = []
        rmse_list1 = []
        r2_list1 = []
        mae_list2 = []
        mse_list2 = []
        rmse_list2 = []
        r2_list2 = []


        results.loc[index]= [round(avg_mae1,3), round(avg_rmse1, 3), round(avg_mse1, 3), round(avg_r21, 3), round(avg_mae2,3), round(avg_rmse2, 3), round(avg_mse2, 3), round(avg_r22, 3)]
        results.rename(index={index: grid}, inplace=True)

    #results are exported
    new = results.T
    new.to_excel('assets/test_random_selection/RF'+TARGET+par+'.xlsx')
    new.to_csv('assets/test_random_selection/RF'+TARGET+par+'.csv')
# Out:
# 0_1_mountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  5.648218575833811
# Root Mean Squared Error:  7.374647128773565
# Mean Squared Error:  55.20374109865171
# R2 score:  0.7995171338246674
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  14.987673213308593
# Root Mean Squared Error:  16.469101306542434
# Mean Squared Error:  273.3229255857121
# R2 score:  -0.061315248815607126
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.9787137258577254
# Root Mean Squared Error:  2.784080390276662
# Mean Squared Error:  8.025219211237909
# R2 score:  0.8241183383345021
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  10.76414337407019
# Root Mean Squared Error:  11.63881256254643
# Mean Squared Error:  136.0156075902114
# R2 score:  -2.0465742369371327
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  3.057964081190537
# Root Mean Squared Error:  4.042434864011086
# Mean Squared Error:  16.78054894761337
# R2 score:  0.8777462903756129
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.149613442649235
# Root Mean Squared Error:  11.890634139028355
# Mean Squared Error:  149.73834189434393
# R2 score:  -0.00911509224437863
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  5.771193850424009
# Root Mean Squared Error:  7.703953053653751
# Mean Squared Error:  59.686367692130034
# R2 score:  0.7453361391866187
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  10.323495186669415
# Root Mean Squared Error:  13.762661398635405
# Mean Squared Error:  193.932536168189
# R2 score:  0.21245003651156685
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.886733857310444
# Root Mean Squared Error:  3.1076736574406367
# Mean Squared Error:  11.2460069385603
# R2 score:  0.8356888009839952
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  9.168260992041581
# Root Mean Squared Error:  10.10653631529589
# Mean Squared Error:  103.07652876890783
# R2 score:  -1.2869848751751016
#
#
#
#
#
#
#
#
#
#
# 0_1_nomountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  4.25506055804975
# Root Mean Squared Error:  5.59987844145841
# Mean Squared Error:  31.86555512571643
# R2 score:  0.8675007861823234
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  15.378159987747614
# Root Mean Squared Error:  16.945737047380184
# Mean Squared Error:  287.76288387695064
# R2 score:  -0.16961697870987552
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  2.377560270710675
# Root Mean Squared Error:  3.0431605088260154
# Mean Squared Error:  9.552279795804457
# R2 score:  0.7119073484700055
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  10.743072849071057
# Root Mean Squared Error:  11.616339638228116
# Mean Squared Error:  137.78874875509382
# R2 score:  -3.3202815691908327
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  3.5580078681196996
# Root Mean Squared Error:  5.076338734459238
# Mean Squared Error:  26.513146835567646
# R2 score:  0.7538625181826768
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  8.792459512731998
# Root Mean Squared Error:  12.759598156259639
# Mean Squared Error:  172.50072356019845
# R2 score:  -0.19479421367824185
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  4.580610858023058
# Root Mean Squared Error:  6.376929878884804
# Mean Squared Error:  44.62837332321296
# R2 score:  0.8101368473946868
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  10.303801098943023
# Root Mean Squared Error:  14.463610040312375
# Mean Squared Error:  211.5690268405809
# R2 score:  0.07996333513903875
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.8663589783774008
# Root Mean Squared Error:  2.9406413500850594
# Mean Squared Error:  10.469776303411221
# R2 score:  0.863208258152417
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  9.497304926730676
# Root Mean Squared Error:  10.436548030003234
# Mean Squared Error:  110.81994019993826
# R2 score:  -1.1217843332655892
#
#
#
#
#
#
#
#
#
#
# 0_01_mountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.47046585247456907
# Root Mean Squared Error:  0.8045176040205367
# Mean Squared Error:  0.690028884285174
# R2 score:  0.9984697507838358
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  17.69414526868097
# Root Mean Squared Error:  18.522535893245685
# Mean Squared Error:  343.1119423392631
# R2 score:  0.2022507874981859
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.21814494274850388
# Root Mean Squared Error:  0.37270321597030515
# Mean Squared Error:  0.14635336938669916
# R2 score:  0.9978996582880331
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  10.535925770975238
# Root Mean Squared Error:  12.052114818288933
# Mean Squared Error:  145.43290261531203
# R2 score:  -1.2369044161181477
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.5163711987226687
# Root Mean Squared Error:  1.2823490198511145
# Mean Squared Error:  2.06398459006015
# R2 score:  0.991087537273537
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  11.048943329024329
# Root Mean Squared Error:  16.90603560163107
# Mean Squared Error:  287.76142344437903
# R2 score:  -0.04017887693360813
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.6858430034749405
# Root Mean Squared Error:  1.8826325150854832
# Mean Squared Error:  4.87231112151895
# R2 score:  0.9883194804101606
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  13.328515682844834
# Root Mean Squared Error:  19.402376315568848
# Mean Squared Error:  382.8786662794403
# R2 score:  0.11610809490092566
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.5064676978644013
# Root Mean Squared Error:  1.5027964509463299
# Mean Squared Error:  3.421622530658503
# R2 score:  0.9805511673286518
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  11.479587322599897
# Root Mean Squared Error:  12.97578527506325
# Mean Squared Error:  169.03006458443687
# R2 score:  -0.12187925705017069
#
#
#
#
#
#
#
#
#
#
# 0_01_nomountains
# ---------0324_0331_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.6646273620559564
# Root Mean Squared Error:  1.7323705798012738
# Mean Squared Error:  3.7138500749427363
# R2 score:  0.990921109958393
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  18.400550924362044
# Root Mean Squared Error:  19.200188849289997
# Mean Squared Error:  368.8577378582434
# R2 score:  0.13683255705280076
# ---------0418_0425_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.2114350505743979
# Root Mean Squared Error:  0.43086778839125034
# Mean Squared Error:  0.26531247596359175
# R2 score:  0.9956504270088677
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  10.413581388742672
# Root Mean Squared Error:  12.13231437518106
# Mean Squared Error:  147.65157050206932
# R2 score:  -1.6313479165872784
# ---------0717_0724_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  1.3132758856622426
# Root Mean Squared Error:  3.9181301416018264
# Mean Squared Error:  26.521213123619436
# R2 score:  0.8745172043116283
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  11.745972724714752
# Root Mean Squared Error:  17.8966293498959
# Mean Squared Error:  323.4184478756978
# R2 score:  -0.15012945957029813
# ---------0903_0910_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.9788849389928302
# Root Mean Squared Error:  2.7536254841338854
# Mean Squared Error:  10.884740258572448
# R2 score:  0.9729852738873209
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  14.173030483830626
# Root Mean Squared Error:  21.199710947577866
# Mean Squared Error:  455.80888342504323
# R2 score:  0.022123883915765186
# ---------1007_1014_2021---------
# Iteration n°:   1
# Iteration n°:   2
# Iteration n°:   3
# Iteration n°:   4
# Iteration n°:   5
# ---------VALIDATION (ARPA)  ---------
# Mean Absolute Error:  0.5562700808767567
# Root Mean Squared Error:  1.2801183519204056
# Mean Squared Error:  2.022089002072795
# R2 score:  0.9885700912168994
# ---------VALIDATION (CAMS) ---------
# Mean Absolute Error:  12.013957504997949
# Root Mean Squared Error:  13.700784155204966
# Mean Squared Error:  188.67108537695916
# R2 score:  -0.07111444223753594
